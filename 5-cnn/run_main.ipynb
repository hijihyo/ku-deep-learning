# %%
#!python3 hw5.py

# %%
# %%bash
#
# lr=0.1
# ns=1024
# echo "$lr $ns" && python3 hw5.py $lr $ns | grep total
# Out:
# 0.1 1024
# total accuray 0.9333999999999998
# tcmalloc: large alloc 1618477056 bytes == 0x55addb876000 @  0x7fb77e5911e7 0x7fb77b01d46e 0x7fb77b06dc7b 0x7fb77b06dd97 0x7fb77b0674a5 0x7fb77b13829c 0x7fb77b105dd1 0x55ad68ea44b0 0x55ad68f95e1d 0x55ad68f17e99 0x55ad68ea5afa 0x55ad68f13c0d 0x55ad68ea5afa 0x55ad68f13c0d 0x55ad68ea5afa 0x55ad68f13c0d 0x55ad68f129ee 0x55ad68f126f3 0x55ad68fdc4c2 0x55ad68fdc83d 0x55ad68fdc6e6 0x55ad68fb4163 0x55ad68fb3e0c 0x7fb77d37bbf7 0x55ad68fb3cea
# tcmalloc: large alloc 1618477056 bytes == 0x55ade7d56000 @  0x7fb77e5911e7 0x7fb77b01d46e 0x7fb77b06dc7b 0x7fb77b06dd97 0x7fb77b0674a5 0x7fb77b13829c 0x7fb77b105dd1 0x55ad68ea44b0 0x55ad68f95e1d 0x55ad68f17e99 0x55ad68ea5afa 0x55ad68f13c0d 0x55ad68ea5afa 0x55ad68f13c0d 0x55ad68ea5afa 0x55ad68f13c0d 0x55ad68f129ee 0x55ad68f126f3 0x55ad68fdc4c2 0x55ad68fdc83d 0x55ad68fdc6e6 0x55ad68fb4163 0x55ad68fb3e0c 0x7fb77d37bbf7 0x55ad68fb3cea
# ...

# %%
# %%bash
#
# learning_rates=(1 1)
# # learning_rates=(1)
#
# # num_steps=(32 64 128 256 512 1024)
# batch_size=(512 1024)
#
# for lr in ${learning_rates[@]}
# do
#     for bs in ${batch_size[@]}
#     do
#         echo "$lr $bs $(date)" && python3 hw5.py $lr $bs | grep total
#     done
# done
# echo "end at $(date)";
# Out:
# 1 512 Mon Dec  6 14:24:42 UTC 2021
# total accuray 0.9800999999999997
# 1 1024 Mon Dec  6 14:31:39 UTC 2021
# total accuray 0.9716999999999998
# 1 512 Mon Dec  6 14:38:17 UTC 2021
# total accuray 0.9761999999999991
# 1 1024 Mon Dec  6 14:45:17 UTC 2021
# total accuray 0.9724999999999998
# end at Mon Dec  6 14:51:55 UTC 2021
# tcmalloc: large alloc 1618477056 bytes == 0x558bda6f8000 @  0x7f84971e91e7 0x7f8493c7546e 0x7f8493cc5c7b 0x7f8493cc5d97 0x7f8493cbf4a5 0x7f8493d9029c 0x7f8493d5ddd1 0x558b693554b0 0x558b69446e1d 0x558b693c8e99 0x558b69356afa 0x558b693c4c0d 0x558b69356afa 0x558b693c4c0d 0x558b69356afa 0x558b693c4c0d 0x558b693c39ee 0x558b693c36f3 0x558b6948d4c2 0x558b6948d83d 0x558b6948d6e6 0x558b69465163 0x558b69464e0c 0x7f8495fd3bf7 0x558b69464cea
# ...
